# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,3,4],[5,6,7,8])

# %%
plt.show()

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %%
plt.title('Straight Line Graph')
# Out:
# Text(0.5, 1.0, 'Straight Line Graph')

# %%
# x value default
plt.plot([10,20,30,40],'r-',linewidth = 20,markersize = 20)

# %%
plt.plot([10,20,30,40],'ro',markersize=20)

# %% [markdown]
# # Colours
# - b blue
# - m magenda
# - c cyan
# - k black
# - o orange
# - g green
# - y yellow
# - w white

# %%
a = np.arange(1,100,0.5)
plt.plot(a,"go:",a**2,"r^--",a**3,"c-.")
# Out:
# [<matplotlib.lines.Line2D at 0x1fff8ba7400>,
#  <matplotlib.lines.Line2D at 0x1fff8ba74c0>,
#  <matplotlib.lines.Line2D at 0x1fff8ba75e0>]
